# %%
# Alchemy API Setup

from alchemy import Alchemy, Network
from web3 import Web3
from dotenv import load_dotenv, set_key
from pymongo import MongoClient
import os
import time
import json

# create Alchemy object using your Alchemy api key, default is "demo"
load_dotenv('../.env')
api_key = os.getenv('ALCHEMY_API_KEY')

# choose preferred network from Network, default is ETH_MAINNET
network = Network.ETH_MAINNET

# choose the maximum number of retries to perform, default is 5
max_retries = 3

# create Alchemy object
alchemy = Alchemy(api_key, network, max_retries=max_retries)

# %%
# Web3 API Setup
load_dotenv('../.env')
w3 = Web3(Web3.HTTPProvider(os.getenv('HTTPProvider')))

# %%
# Get block data from Alchemy
block_hash_alc = Alchemy.to_hex(alchemy.core.get_block('latest')['hash'])

# Get block data from Web3
block_data_w3 = w3.eth.get_block('latest')

print(f"Alchemy Block Hash: {block_hash_alc}")
print(f"Web3 Block Data: {block_data_w3}")
print("Web3 Block Data:")
for key, value in block_data_w3.items():
    if type(block_data_w3[key]) is list:
        for i in block_data_w3[key]:
            print(f"    {i}")
    else:
        print(key, value)
# Out:
# Alchemy Block Hash: 0x056074cc61544459cafad6c08f17078ddc2aa5a99a8748902eb16183350a2697
# Web3 Block Data: AttributeDict({'baseFeePerGas': 1669403693, 'blobGasUsed': 0, 'difficulty': 0, 'excessBlobGas': 393216, 'extraData': HexBytes('0x6265617665726275696c642e6f7267'), 'gasLimit': 30000000, 'gasUsed': 14310994, 'hash': HexBytes('0x056074cc61544459cafad6c08f17078ddc2aa5a99a8748902eb16183350a2697'), 'logsBloom': HexBytes('...'), 'miner': '0x95222290DD7278Aa3Ddd389Cc1E1d165CC4BAfe5', 'mixHash': HexBytes('0x2d1d53b83b4ce4b181db978e9a97a55037bf3fa8aa30b2a232315551c0cb403b'), 'nonce': HexBytes('0x0000000000000000'), 'number': 20526665, 'parentBeaconBlockRoot': HexBytes('0x131fb6ed1fd8e5d377991e016e974be9b30b62d28f08a20fd5a790d73e5b2e18'), 'parentHash': HexBytes('0x4e2dffc257ac235702bc6f245edecfe6970063093b5f42821b096c258a5eaff4'), 'receiptsRoot': HexBytes('0x353b7e87313cae0179a802bfccd706a18b7ab15a6270c6156d15d08a9c867fbe'), 'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'), 'size': 74462, 'stateRoot': HexBytes('0xbbca1673a7f47f16dea3bd9bf30bb12264cfcb7c7846e8e39b605b1aa6ac093a'), 'timestamp': 1723636031, 'totalDifficulty': 58750003716598352816469, 'transactions': [HexBytes('0x72a7820d922f34e32cbd4e6c472bb1e6588510288c9726437454e8cd8c1c5d5a'), HexBytes('0xe0e6e5e6856d79972fd66b45d5ae74a5422c898f34109c0f738476000180b37d'), HexBytes('0xa55c50dbbd05eb0e5189ff1e8d3fccb039214e43dadac58bb6ef506a5e0848ce'), HexBytes('0xbcee91397202ccb3f1f3a1a6b553e41414aeb35d7039939f85a57a1cea78787c'), HexBytes('0x8daccf595f37eaba537ce9a4d21c078dced321e0dec4629864171f634ace5106'), HexBytes('0x71021f64715502f871b7b748d34d4342e41dcba436a3a90293925de33b222995'), HexBytes('0x661813087e99c13ae60ccc8e1f52e4c5067d6b7faac5a86b62e02a6858ba8eba'), HexBytes('0x9333c003371d9cdb009358174b5b4acb9546d1c7282f22ed3a6a7379114fce21'), HexBytes('0x16b71dc5f7d26a161114760995c1b0dc68d4858c51cd5d468313a0a32c6661af'), HexBytes('0x137af32ef7ad3ecd9c45f43a4ea833d1e0dd90f37bd289e9a979e73cbe9efd5d'), HexBytes('0xc19ce180c876322e785dc6da7e8984363b6ff58723c2fea04a7ba32fb241dd02'), HexBytes('0x04f188493faa8a5f900b0cda3b645b59e90a5a4df40ec17659447172f51b9aee'), HexBytes('0x0789c14f00858e784d8da9923a6002be91298952bd396cdef1dc09749cc76fc0'), HexBytes('0x8b939c8c4bd2abeff60eab030111e00d5f0876f15af4ab1a7484f99b1e196b9a'), HexBytes('0xffacd43498d4c5d7fc93da531a501e60c1a4eb78ad073570d75e35d70dbfb501'), HexBytes('0xb03d524bd76865c2c65edab7613ea49ad3228b24157dad85da1abc43327f4431'), HexBytes('0x9aa98b9c6db0ecb39f25d6e11d08873231abaedd57ba06fbad26ab6545a700a8'), HexBytes('0x71a4f1d6e005e3dec84ce429be5209a39fe6c209c928db3f63a5c1d05da86bba'), HexBytes('0x0a4bdcecbcfc2dd8ff2c2d626a50c704aeaa8d8429f195a14935e1868ed838e8'), HexBytes('0xa9403d77676fd19e57c078bbd4559af2b42ff76c29f63caca011283d523e9667'), HexBytes('0x094bd95ec73771bfb3aaf50d6c48e08bf0dd8528da5781d56f8f851c266ad550'), HexBytes('0xac41234314d0787b34dd676a2bdc1f240d7a239f34e2b4c529c249d81416fe36'), HexBytes('0x65c433c7d1ffe99ba5bb3820de945a1395130eb30be36d95c764ce9dd8177aba'), HexBytes('0x0d6cac750f78fc7463b2b88526fac2b392e87b3685432d7dbf18ded11a014671'), HexBytes('0xe4afe036aa48bbaf6aa20f8d20595531e087da84995055c8c768b6d0bb9fe0e7'), HexBytes('0x0db6a9bb3234cfba9133ea7eec55212d38a5b33eefb90ba017a95eeff6cd03c3'), HexBytes('0x48f0652d64f69529ef1d0542701182cc3fcc587b3325528f3ff0f1998210e554'), HexBytes('0xc5b4f30e7336ed2272da60f0ed820dad724332ce0fea20c841efab4d45f3303e'), HexBytes('0x775430d3fddd5b4a8abef63208e68f04b5ca492b369d12920cc6ad3efaea72b1'), HexBytes('0xe55c26c4cfb4e87a503897ea4c992cf0b6a2b600506a82cbd2dd77c72b649682'), HexBytes('0xe2d753a2a35d9eb3ac9faf70504a5cb77470083dd192f26661170627f3cefff9'), HexBytes('0x25d48025ebb8f4d17d170718dcdbf93d1b8174b7f97960ff9b0fcffc031cd291'), HexBytes('0x472c1f7c621c6041e173d99893019d42763f3c7a94268286a1dcbaff0a6050e1'), HexBytes('0x05f00be9cbbcea46e0a45c02710480f20cdabcb634dd9a6ff17be5eef20080e4'), HexBytes('0x640095cca0961a3a365043b8632c0616eb1a80da9e8495f58a66eb5a38b775c1'), HexBytes('0x0249845df9d8531bfc4d4f658e1ee98282200f7425f31cfc14a36ed49 ...
# Web3 Block Data:
# baseFeePerGas 1669403693
# blobGasUsed 0
# difficulty 0
# excessBlobGas 393216
# extraData b'beaverbuild.org'
# gasLimit 30000000
# gasUsed 14310994
# hash b'\x05`t\xccaTDY\xca\xfa\xd6\xc0\x8f\x17\x07\x8d\xdc*\xa5\xa9\x9a\x87H\x90.\xb1a\x835\n&\x97'
# logsBloom b'\x83\xa1)\xab\xe5\xab\x01x\x9a\x8d\xb47\x86\tL=6e\xe0\x87\xadU\x99\xaa \rD\x98\x0f\xe9\x8e\x8d\x16\xdf\x9d(\xa89]\x12\xba\xc3{\x01\x17\xbcY\x0f6\x91\xc9\xab\x9c\xe3\xeb5f\xbbbIe)!\r\xf1V\x9d-\x11\x97\x99O9&a\xcd\xc8\xe1a\xf3\x03\x15`}\x90pH9}F\x8d,\xd2gF\xc6\x18bR\xf9R\xacw\xff\x8b\tV\x9d[\x88\xfd\x95?c\x84kI\xd2\xfc\x94W\x013\xfc\x80\xd8\x94\xb1u\xe0\xb2\xf6X\xd2\xdb\x8e\x1eO\xab\xc2\xab\xecAv\x08\x97\xd5\xa1\xa3u\xc1Z\xfe$[OQ\xb2\xad\x88\x8f\xe6\x8e/\xaf\xa7\xae\xfe\x1b\xd13\xc0\\\xe0-[\xc4-\xad\x18x\xbe\x1ah\x9c-Jc(\xba\xf4uM\x83|J\xb2\x15+\xfbAI+\x0bJ\xb9\x9a\xece\xb0\n\x93\xee\x0cd\x9c&\xa9b>H\xb7\xa5\x8ag{\xe8(\x93\x98\x04\xb9\x9d&\x99\xc0\x8a\xd1\x11W\x05(\xb3}\x93\xeb&\xd4:A\xdb\x07|\xe9\x9c.'
# miner 0x95222290DD7278Aa3Ddd389Cc1E1d165CC4BAfe5
# mixHash b'-\x1dS\xb8;L\xe4\xb1\x81\xdb\x97\x8e\x9a\x97\xa5P7\xbf?\xa8\xaa0\xb2\xa221UQ\xc0\xcb@;'
# nonce b'\x00\x00\x00\x00\x00\x00\x00\x00'
# number 20526665
# parentBeaconBlockRoot b'\x13\x1f\xb6\xed\x1f\xd8\xe5\xd3w\x99\x1e\x01n\x97K\xe9\xb3\x0bb\xd2\x8f\x08\xa2\x0f\xd5\xa7\x90\xd7>[.\x18'
# parentHash b'N-\xff\xc2W\xac#W\x02\xbco$^\xde\xcf\xe6\x97\x00c\t;_B\x82\x1b\tl%\x8a^\xaf\xf4'
# receiptsRoot b'5;~\x871<\xae\x01y\xa8\x02\xbf\xcc\xd7\x06\xa1\x8bz\xb1Zbp\xc6\x15m\x15\xd0\x8a\x9c\x86\x7f\xbe'
# sha3Uncles b'\x1d\xccM\xe8\xde\xc7]z\xab\x85\xb5g\xb6\xcc\xd4\x1a\xd3\x12E\x1b\x94\x8at\x13\xf0\xa1B\xfd@\xd4\x93G'
# size 74462
# stateRoot b'\xbb\xca\x16s\xa7\xf4\x7f\x16\xde\xa3\xbd\x9b\xf3\x0b\xb1"d\xcf\xcb|xF\xe8\xe3\x9b`[\x1a\xa6\xac\t:'
# timestamp 1723636031
# totalDifficulty 58750003716598352816469
#     b'r\xa7\x82\r\x92/4\xe3,\xbdNlG+\xb1\xe6X\x85\x10(\x8c\x97&CtT\xe8\xcd\x8c\x1c]Z'
#     b'\xe0\xe6\xe5\xe6\x85my\x97/\xd6kE\xd5\xaet\xa5B,\x89\x8f4\x10\x9c\x0fs\x84v\x00\x01\x80\xb3}'
#     b'\xa5\\P\xdb\xbd\x05\xeb\x0eQ\x89\xff\x1e\x8d?\xcc\xb09!NC\xda\xda\xc5\x8b\xb6\xefPj^\x08H\xce'
#     b'\xbc\xee\x919r\x02\xcc\xb3\xf1\xf3\xa1\xa6\xb5S\xe4\x14\x14\xae\xb3]p9\x93\x9f\x85\xa5z\x1c\xeaxx|'
#     b'\x8d\xac\xcfY_7\xea\xbaS|\xe9\xa4\xd2\x1c\x07\x8d\xce\xd3!\xe0\xde\xc4b\x98d\x17\x1fcJ\xceQ\x06'
#     b'q\x02\x1fdqU\x02\xf8q\xb7\xb7H\xd3MCB\xe4\x1d\xcb\xa46\xa3\xa9\x02\x93\x92]\xe3;")\x95'
#     b'f\x18\x13\x08~\x99\xc1:\xe6\x0c\xcc\x8e\x1fR\xe4\xc5\x06}k\x7f\xaa\xc5\xa8kb\xe0*hX\xba\x8e\xba'
#     b'\x933\xc0\x037\x1d\x9c\xdb\x00\x93X\x17K[J\xcb\x95F\xd1\xc7(/"\xed:jsy\x11O\xce!'
#     b'\x16\xb7\x1d\xc5\xf7\xd2j\x16\x11\x14v\t\x95\xc1\xb0\xdch\xd4\x85\x8cQ\xcd]F\x83\x13\xa0\xa3,fa\xaf'
#     b'\x13z\xf3.\xf7\xad>\xcd\x9cE\xf4:N\xa83\xd1\xe0\xdd\x90\xf3{\xd2\x89\xe9\xa9y\xe7<\xbe\x9e\xfd]'
#     b'\xc1\x9c\xe1\x80\xc8v2.x]\xc6\xda~\x89\x846;o\xf5\x87#\xc2\xfe\xa0J{\xa3/\xb2A\xdd\x02'
#     b'\x04\xf1\x88I?\xaa\x8a_\x90\x0b\x0c\xda;d[Y\xe9\nZM\xf4\x0e\xc1vYDqr\xf5\x1b\x9a\xee'
#     b'\x07\x89\xc1O\x00\x85\x8exM\x8d\xa9\x92:`\x02\xbe\x91)\x89R\xbd9l\xde\xf1\xdc\tt\x9c\xc7o\xc0'
#     b'\x8b\x93\x9c\x8cK\xd2\xab\xef\xf6\x0e\xab\x03\x01\x11\xe0\r_\x08v\xf1Z\xf4\xab\x1at\x84\xf9\x9b\x1e\x19k\x9a'
#     b'\xff\xac\xd44\x98\xd4\xc5\xd7\xfc\x93\xdaS\x1aP\x1e`\xc1\xa4\xebx\xad\x075p\xd7^5\xd7\r\xbf\xb5\x01'
#     b'\xb0=RK\xd7he\xc2\xc6^\xda\xb7a>\xa4\x9a\xd3"\x8b$\x15}\xad\x85\xda\x1a\xbcC2\x7fD1'
#     b'\x9a\xa9\x8b\x9cm\xb0\xec\xb3\x9f%\xd6\xe1\x1d\x08\x8721\xab\xae\xddW\xba\x06\xfb\xad&\xabeE\xa7\x00\xa8'
#     b'q\xa4\xf1\xd6\xe0\x05\xe3\xde\xc8L\xe4)\xbeR\t\xa3\x9f\xe6\xc2\t\xc9(\xdb?c\xa5\xc1\xd0]\xa8k\xba'
#     b'\nK\xdc\xec\xbc\xfc-\xd8\xff,-bjP\xc7\x04\xae\xaa\x8d\x84)\xf1\x95\xa1I5\xe1\x86\x8e\xd88\xe8'
#     b'\xa9@=wgo\xd1\x9eW\xc0x\xbb\xd4U\x9a\xf2\xb4/\xf7l)\xf6<\xac\xa0\x11(=R>\x96g'
#     b'\tK\xd9^\xc77q\xbf\xb3\xaa\xf5\rlH\xe0\x8b\xf0\xdd\x85(\xdaW\x81\xd5o\x8f\x85\x1c&j\xd5P'
#     b'\xacA#C\x14\xd0x{4\xddgj+\xdc\x1f$\rz#\x9f4\xe2\xb4\xc5)\xc2I\xd8\x14\x16\xfe6'
#     b'e\xc43\xc7\xd1\xff\xe9\x9b\xa5\xbb8 \xde\x94Z\x13\x95\x13\x0e\xb3\x0b\xe3m\x95\xc7d\xce\x9d\xd8\x17z\xba'
#     b'\rl\xacu\x0fx\xfctc\xb2\xb8\x85&\xfa\xc2\xb3\x92\xe8{6\x85C-}\xbf\x18\xde\xd1\x1a\x01Fq'
#     b'\xe4\xaf\xe06\xaaH\xbb\xafj\xa2\x0f\x8d YU1\xe0\x87\xda\x84\x99PU\xc8\xc7h\xb6\xd0\xbb\x9f\xe0\xe7'
#     b'\r\xb6\xa9\xbb24\xcf\xba\x913\xea~\xecU!-8\xa5\xb3>\xef\xb9\x0b\xa0\x17\xa9^\xef\xf6\xcd\x03\xc3'
#     b'H\xf0e-d\xf6\x95)\xef\x1d\x05Bp\x11\x82\xcc?\xccX{3%R\x8f?\xf0\xf1\x99\x82\x10\xe5T'
#     b'\xc5\xb4\xf3\x0es6\xed"r\xda`\xf0\xed\x82\r\xadrC2\xce\x0f\xea \xc8A\xef\xabME\xf30>'
#     b'wT0\xd3\xfd\xdd[J\x8a\xbe\xf62\x08\xe6\x8f\x04\xb5\xcaI+6\x9d\x12\x92\x0c\xc6\xad>\xfa\xear\xb1'
#     b'\xe5\\&\xc4\xcf\xb4\xe8zP8\x97\xeaL\x99,\xf0\xb6\xa2\xb6\x00Pj\x82\xcb\xd2\xddw\xc7+d\x96\x82'
#     b"\xe2\xd7S\xa2\xa3]\x9e\xb3\xac\x9f\xafpPJ\\\xb7tp\x08=\xd1\x92\xf2fa\x17\x06'\xf3\xce\xff\xf9"
#     b'%\xd4\x80%\xeb\xb8\xf4\xd1}\x17\x07\x18\xdc\xdb\xf9=\x1b\x81t\xb7\xf9y`\xff\x9b\x0f\xcf\xfc\x03\x1c\xd2\x91'
#     b'G,\x1f|b\x1c`A\xe1s\xd9\x98\x93\x01\x9dBv?<z\x94&\x82\x86\xa1\xdc\xba\xff\n`P\xe1'
#     b'\x05\xf0\x0b\xe9\xcb\xbc\xeaF\xe0\xa4\\\x02q\x04\x80\xf2\x0c\xda\xbc\xb64\xdd\x9ao\xf1{\xe5\xee\xf2\x00\x80\xe4'
#     b'd\x00\x95\xcc\xa0\x96\x1a:6PC\xb8c,\x06\x16\xeb\x1a\x80\xda\x9e\x84\x95\xf5\x8af\xebZ8\xb7u\xc1'
#     b'\x02I\x84]\xf9\xd8S\x1b\xfcMOe\x8e\x1e\xe9\x82\x82 \x0ft%\xf3\x1c\xfc\x14\xa3n\xd4\x91t\xf6\xab'
#     b"\x99\xb1\x8e%5\xa3\x0fs!\r\xb0:H\xde'\x10\nm\xab\x886\x85\xaf\x02\xf1\xb1t\xfa+\xd7\x1c\x07"
#     b'\x02\x14\x9a\x7f\xb1\xd8\xd7\xc2\x05P\tsG\xeb\x14\x15\x0c\xf9\xfbZ\xab#c\xb1DG\xb6\xd6\xc0\x104\xfa'
#     b'Lv<\x04\x93a\xf8\x9d\xb6v\xf5w\x9b\xdb\x0b\xb3a\xb2\xc3\x1b\xe8\x8d\xd4\x15\xb5\x99\x16)\xf3h>\xb1'
#     b'Zw\xe5W\xa9?\x0b\xbf\xcfW\n\xc4\x06\xc1\xcc\xa5=\x82M\x82\xb5N\x99l\xc0[\x9e\x14\x07\x16\xa2\xc7'
#     b'\xcd\xa2X\xb8\xd0\xc2\x1d\x8e\xac\x8a\x99\x98>nI\xadj\xd7\xe4\xd2\xd2a\x05P\x06\xbb\xd6\xc5Z?\x84\xa8'
#     b'\x8d=}\xff@\xd0\x12f\xddx\xcfw\x15\xd3o\xd8\xfe\xf0\x91F\x87\x9b\x19K\xd92\x98gm\x7f\xf4\x95'
#     b'\xd2\xe2\x1f\x8c]H\xfb\xf3\xd2\\\x7f\x907A\x93{\xa5s,\xc9\t\xf4\xb2!\xdeQ\x05\xeb\x1c{\xf5r'
#     b"&[`ahE\xa1\xe9\x1d\xa8\xb8\x1b\xe9\x0cA$\xa6\xde\xe9K\xf2\xed(T'y\x817\x0c\xcf?<"
#     b'4\xe7TU<\xf0u$=\x88w5\xa4\xf6\t]B\xfe\xceP\xd6\x1b\x98\x8e\xf9:6\x96U\x92\x81\x92'
#     b'\xc1;\x9a\xbeH\xf2\xb6$\xd7J\x08&d6\x8a\x8c\xdb\xfc\n\x8b\x94\x1dl\xff\xfbg\xf1r\xe8{v2'
#     b'Cc\xbd\xc6C\xdc3\x82\x14\xbd\xaf\xf8THR\xb8&1b/,\x95\xeb\x9c:\xc1\x92r\xaf\xb4\xafn'
#     b'\xef:]"\xe0_xD\xc2\xf5\x82\x90\xb2B\xa4C\x89\xde\xef\x93U\xa7=\xa1\xd2\xae\xdcB\xc4|u\x86'
#     b'\x1b\xda\x00\x89\xe63\xff\x85C\xccNXmj\xc5\x10f\x13\x11\xean\x0fA\xb4(\xf0\xf9o\x91\xfe-C'
#     b'\xc5)\x81\n\xc1\x90w\xa9\xe2\x93\xa3\xf8]>\xc4\xdd\x99#\x1b[]\xc8\xa8\xa7\x0e\x0c7[\x87\xc4\xc78'
#     b'\x822YQo\xec\x832\x8d;@,\x10\x08\xcb\x1f\xe4\xeb\xb0\x19eg\xf0]D\xbe(\tE[\xb3\xde'
#     b'\x02MN\xdcb\x1f!\xf4\xd9\x82\xb2a\xcbkG\x8e\xfa\x8c\xbaG\x89\xb1.\xb3\xbfZ\x99\xa2\xc4s\xb6\x94'
#     b'z\x17\xcfh\x05\xd0s\xa3\x9b\x17\x9a\xff\x07\xff\x86\x96;\xde\x03\x1e\x98\xbc^\xe4\xb0\xa0\xd7\xa9.\x17\xb2\xa9'
#     b'\xb1\xc0}\xa5K\xe1\x08-7\x7f\xc72\x15m\xc0\xfb\xacm\xf2k\xdba\xf8\x9a\x0f\xf4\xd7\xbb5Q!\xf9'
#     b'8\x02>l\xc6\xd6\xc7|\xab\xb9\xe0\xa3v\xf1\xbb-kF\xfa\xceV\xd8\x15\xa5\xe7h\x91<\x16\xa9\x03\xd1'
#     b'sM\xb2Le\x9f\xc2\xe4\x96}\xe9\xb6Z\xd7t\xc2k\xf4M\xa7\xa7\x80\x86\x950\xa8\xc2\x98\n\xaf\xde7'
#     b'ZU\x1a\x88%\xe1\x9c\xc0\x05\xf3+P\xc0$\xe3\x12T\x0c_\xb8\xfc\x13\xcc=\x9c\xed)\xd9\x10\x85\xec\x97'
#     b'!\x00\xc6\xe8\xd95\x84xVe\xc1"\x9a-\xdf&\xb5\x89P\xa6M\x90\xb5\xd5\xb6v\xfc)6hk\xe5'
#     b'\x91\xe8\xeenL7o(\x06\x97Hn"\xa9\xd5\xf4\xa9{\xfb\xf0~5&\xbe\x1ai\x03\xf0\xd3\x85\xb2\xea'
#     b'\r\x0b\xfbM[\x85\xd3\x86\xdf\x1d\x8f\xbeXmA\x15m\xc7\xf5\xc1d\xbd7q\xa9@\xb4\xb8\x08\x98\xb7\xfd'
#     b'\xae\xbf\xa0\xcc\xe8\xe8\xa1\xd5U\x97\x1e\xc8\xc8\x00\x95\x966,\x1aLJ\x0bc\x8d\x0f(\x15D\xe1\xa7\xe1\x88'
#     b's\xdd\xdf\xc4\xa4\x9e{&[\x0c\x12\x05]t\x9e\x18\x10\xefO=\x8cK\xc2\x99\xf0\xd0\x1b\xeb@\x82Yl'
#     b'\x97\xd0\xfc\xd5\xc7\xf6\xd1\xf8\xda\xedd\t\x12b\r\n8D\x99|\xf4JO\x10\x91\xf5wR\x883)\xb4'
#     b',\n-\xccdt\x19t4\x05t\xf5\xa4nl\xf9\xc6\x0b~\xad\xb9P\x0c*\xcb\xe5\xf1!Q\x89\xfc\xb1'
#     b'e\xfc+\xc6\xab*/uLC\x04\xbc\xa2\xa0`\x9e\x1d\xb0\xbe\xb5\x8e\xd5Zz\xb7S\x0b\x8d@\xd2\xfc\x89'
#     b"\xb6\x93+_\xa5\xda6 \xd42\x7f.th6l<Y$\xf4\x8a'sR\xbc\x90NG=4=\xa6"
#     b'\xa5\xb8V\x07\xa4\xcf\xe0}\xb9\xd8\xb0\xbec9\x1f\xae\x98\xe0\x05\xfe\x9a\x11j\x03,\xf2\x14H\xbb>$\xc3'
#     b'ndT\x87\xc3\x0c3\xe3DJ\xe1\xe1\xad&ZT\xf8\x0e\xa2\xfc\xa1Q\xb4\xb74I\x80\xb0=\xbbs;'
#     b'\xc9\xfcb|9X\xb709\x1f\xcf\xa7\xab\xf3\xa7`,\xb7\x93\xd0\x85\x10\xe3A0\xa4L\xafr\xe1\xd9a'
#     b'\xa5x\xa1\xc9D\x13\xbf\xf4\xe3g\xd3\xfeHK\x19\xaa\x87\x0b\x91\x1eR\xa5:h\xf9\x8f\xcf\xa1\xbe\xef,\xcd'
#     b'\xcd\x1fs\x80\x19\x81\xc3]\xd0\x81s-1S\x92\x01\xf6\xef\xdb\x86\xb1w\x02~z[zSM\x8a\x94:'
#     b'\xd7\xc4\x80u\x86d0Z\xef8\x18\x8f\xc8\xa8\x87\xd3G\x8f\xe4(\xe5K\xb3\xbd\xe4\x9b\x94\x1a\xfd\xbd\x9c\x0e'
#     b'\xbb$\x88\x9b\xb7w~(\x1e\xdeM\xd2\x01\xd3\xd3\xf3\x11\xae\xd6\xd2\xe1\xc6\x15\x8dt_\xab\x8d\xe8E\x81\x82'
#     b'$)N\xb7` \xd2\xd7E!m\xedsf\xd5\xeew\xec\x9f\xa5\nA\xc2(?\x84\xf7\rL\xd3\x9d\x88'
#     b'\xde\xd9\x9f\xa0\xba\xd7\xddJw\xc9\xc5\xfeH\xd9\xde\xfc7\x15\x84\xc0\xc3\x13i\xa4}\x1b\xd7\xfe\xba\xd8K\xdc'
#     b'\xa2dN\x17\xa8\xf7/W\xde\xe6?\xd0\xe2\xa2x\x96\xe1\xe7\xe54B\xe0\xf3\x13\xf1-\x1d\x1a:\x9b\xbe\xa9'
#     b'M$\xa6\xf5\xc6\xa5$1\xa4\x9d\xbe\x89\xf74qWA\xd4\x85\xe4\xb1\x84\xfa\xa6w\x02~l_\x1dc\x0e'
#     b't\x9f\xf5\xb7\xae\xed\xd3\x13z4NMb\xd2.\x03\x96\n\x8b\xe8\x96o\xe4\x81"\xdf9\x12\x0b\x15,\xe7'
#     b'"\xb3fc\x81\x1c\x8f\xc6L\xfa\xf4\x90|*FR-\x8e\xcd\x92]f J\x91=\xc2\x82\xe8d\x99l'
#     b'\x88N\x13J\xa9"\xdd\x9c\xf6\xc7\x9d5:\xd8+\x99\x04h\x9e\x900\xc4\xc58D&_\xa3\x14\x98\xa9u'
#     b'\xb6q\x02\xaaK^\x8a\r\xb1\xb4,I\xc5\xe7/>\xeb\xe7\x9cIpB\xe0\x06\xeb\x96\xd7+\x1a\x08\x06w'
#     b'!\x1e\xec\x0f\xa7\x1b\xde\xbe\xb1VH\x17\x83\x0eds\xcf\x8de\xbe\x89\x7fI\xcd\x89\x8f\xad\xac\xc16\xe7\xef'
#     b'l\xbd\xf8)\x97\xba\xff\x9a\xc0n{\xdb\xc6t\xd0@\x96E\xa9\x044\xe4\x18\xf6\x98|\x179\x95\x19}\x9d'
#     b'\xd5\xe8n[S\xd5\x12\xb4\n\x06H\x19\x96\xe5\xf42\xbe\xf4x\x8b\xf7\xc0\x0f\xd1j\xcb\xee\xa2\xc1[\xc35'
#     b'T\x01\xb0\xcd\x17\x80\xe8e\xa7\x1e4\x95\xb4;\x88V\xff+\x8e\xec\x99\xf9\xa7\xechY-\xc06\x03\xd9B'
#     b'1U\xa6X\xf7\x88\xe34\xdfo\x9ah\xfb\x0b;\xa3F\x92*\x9c\xb2\xa8\xea\xf2K\xfe7v7\x99\xa9>'
#     b'\xb8y\x01m\x8e\xc1\x90f\x06\xe4\xfb\x11V.\x9c\xa9dB\xa9Eb\x0fj\xe2\x11\x9f\x87\n\xc5\xbe\x7f3'
#     b"\x07?>\xa4\x00^!n\xfe\xec4e\x91@\x12\x92'\x13\xae\xbb\xf9\x15\x9c'\xf4\x16\x12\xf4\x89'U\x0e"
#     b'3\xd9\xec\xc8\xdamo)\xe9\xd8&5\xd7U\x06\xd0\x90^0Y\x95\xe6X\xef\xaa]v\x01?j\xcf\xdf'
#     b'\xb4\xa0/|xo<\xa0\xa1\x16M\xe2\xc7\xb0}\xba\xbf\x0e\xd7gS^a+m\x8ai\x98\xef\xafnd'
#     b"1\xa5J\x13:\xa2\x95>\xc1\xd7\xe3\xdf\x8b\xb0\xf6\xdc\x9e1 \x86\xdf&'\xe9.\x1a\x8c1\x05A\xb9\xef"
#     b'\xfe\x1a\x7fA$Z&f\xf4\xa36W2\x8a\xa6>Z\xe6\x80)\xff\xd3\xddj\xa6\xca \xeb\x1a\x81\xe6\x86'
#     b'\x82\xdc\xea\xcd\x1dJ#}Z[\xd3\xc2\xf21\x14fE|QQ\x12\xed\xd7\xbb\xdf\xd5e\x11$\xc6O@'
#     b'\x8a9Lj4\x00J\xf0\xe0%\xa1\xd3\x9b)\x8a\x07\x06\xdc)gJ#=s\x93N\xfc?\xc2 Pd'
#     b'Z\x89\x18\x08eRU\x9dh\xc6\xd8k!k\xf9!~<F\xf4\xcc\xa4*\xee\xe6\xdf#:\xd6\x03OC'
#     b'aqou\xbe\x9788\x98\xc9\x11\xb6%>n\x84\xe8\xe4\x83i\x1e\xb8\x07\xe9\x12\xc2\xe6\xcb\x1a\xed8\xda'
#     b'&\x1c5\xfa\xeb\xc5\xad\xb7\xb5Q\t\x0f\x92\xbfE\x80\xad\x80\x99&\xb2"\x96Fm\x8aC\x7f\x05\x8a\xc7\x13'
#     b"\xbe'\x0e\x99;\xf0YJ\xce\x17\x9b (\xf9!fl\xb1\xe8\xa0F\xa4\xa9\x05\xfb\xa8\x8dk\x87\xc1\xde^"
#     b'2\x1c\x9c}r\x8dH\xd7\x03\x96\x89s\xdc|[1\x87e<\x92m\xae\x905\xf5\xe6\xf4O\xa6^\xd3\xcc'
#     b'] \xdaV\xc2w\x14\x0fLx\xb3\xbe\xb6\x86;S\xbf\x02\x85\xc8\xfa\x97\xb2\x94W\x14\x0e\xbbw\xc0\xfaF'
#     b'$\x7fi\x93\xd02x\xcf\xb1?\xccKCB\xa4\xe5\xb4@\x7fK0\x7fm\xdb0m\x17\xa6\xaa\x91\xfaS'
#     b'\xe55\xad\xbd\xdf\x04v\xb4V\xad\xbd\x03\xcb\xe1>\xb2yZ0\x83RA\x00q\x11\xcf?\x0c\xdf\x94\x0b\x8c'
#     b'\xe6`\xbbz\xb7\xb5E\xc9/X\x93#\xcf\x94\xb4D\xbe0\x9f\xedI\x01\xb1\xd3\xd8\x95\xfc\x8c\x87\x98\x19/'
#     b'\x91U\xa1\xbe+\x9d\x04Q>\x1be\xe6cb\xfcY\x9d}l\xaf{"L\x91\xba\xcc\xd8B57N\x1a'
#     b'\xee\xfcIo[\x16\xe4\xe59\x03\x88\xcf\xda\xdb\xe9\x80\xf2\xc5y!\x91\xeb\x16\xf7\x7f.\xd0\xbf\x02\xbaJ\x88'
#     b'\xd2AoU\xc1\x10\x9e\xb9\xccU\xaaWM9\x1b\xc4\xf1\xad\xbe\x0c\x06\xed\x99&)\xf1\xa6D_\xf77%'
#     b'\x80\xd3`C\xd3;=\x1f\xdc\xa7\xf3a\x84\xe2\xc9\x94\x01\xcd\x9d\x11w\xc3\x9b\xe7\x1c\xdb\x18\xe4\xbfi!\x87'
#     b'\xe3W\xcd\xe0\xe5W\x06&7\xc0\r\xe7_KO\xc6\xb7$\x80\x97;\x10\xa0\x83\n\x9d\xa5bS\x9d\xea\x9f'
#     b'\x8db\x88H=\x87\x82\xceB\xd5\xea\xc0\xb0S\x05\x82\x13-\xc3j\xe03{\xad|\x9c\xaa\xb5\x15i\x97\xc6'
#     b'U\xdb\xc4a\xc3\x8f?q\x98\x8b\xdb\xb4\xe1J\xf7\xc2_FKx5/\xbe\x12uq\xd3\xb8\x11O\xbc\xa3'
#     b'\xd7\xa2\xad\xc6\x1f\x8f,\x88\xb2:,\xc5\x87e\x93\xd7\xc8y\xbc2\xa6\xf5\x8b\x86\x16:\xc4\x8b\xea\xc1\xb0g'
#     b'9\xcc3\xe0\x1a\x80\xd9@+J\x8b\xb8n"\x9cP\xb11\xc7K\xa5\xdf;\x8e:\xef|\xeb\x1c\xd5 \x1a'
#     b'\x8d\xfbS!I\x8fL\xea\x90y9\xf2s\xf2\xf4\xbed\x1eo!\xa1/t]\xe9\xeb\xf8]:\xff\x1b\xff'
#     b'MY\x98\x1b\xd82\xb8\x03\xd6\x8fC\t%0\xf08\xa7\xef\xb2\xf1\x8a\xef\xc0\x88\xb1S\xf4\xdcu42q'
#     b'\xfc\xd0\xeaS\xbbw\xd4\xbcp\x1b\x87r9\xdb\x1225\x17\xaa*9\xe5\x9dw\xe1\xa7\xff\xa9\x87\xdf\x8a('
#     b'\xca\xdf\xe8D!\x06y\x98\xbf\x00\xb7\xc4B\x1b\x1f\xbc\xb7,\xf8S\xf5\x94\xce\x82\xe2\x97\xd2\xff\xb5\xc3\xf5\x95'
#     b'\xa0\xb9\xfd\x9fh\xca\x1fj\xd9\xba\x90a]\x0fPD\xce\xca\xab\n\x03\x8f\x17\xea\xd1\xac\xef\xcd\x07\xb3\r&'
#     b'\x15\xd0\xb6\xfax\x9e\x87"\x049\xf5\x174\t\xa5\xba\x11\xe1{\xd8\x1d\x05iQ\x11\xc0\xa6=\xbcFP\xb6'
#     b"\x96\xe8\xd2 T\xbc\xc0\xce\x84(\\6#/'\xb6\xb7\xdb\xf3qF\xea\x8b\x1c\x84\xc8\x80\xf5\xe1C\x9dh"
#     b'R\nt\x9b`\xbe\xcf\xf2\xf3\xe1\xd1K\xf5\x08\xc5\x82R\x8c\xfcr\xe0\xac\xe6\xe2\xb3\xf0T<\xac\xfe\xb5]'
#     b'^\xd9\xafC\xa4b\xd1s\xa7Z\x88\xf2X\xbcvbjI\xcc\xe2\x8c\xc3\xad\x9ax\x1bl\xe0O\xbf\xaf\x88'
#     b'\xbf\xc80\x10\xfa\x18\xdc\xfd\xe3\x08\xe63\xbd\xfe\xd5e\x92\x85\x85\x80uD\x0cqL\x0c\x1f\x0f\xad(\x93\x07'
#     b't9\xad\x9f\xea\x86\x10\x84D\x1e\xfb\x12z;\x9b\xc2\xf5\x07\xd3\xda$\x12\xb9\xb9\xdeJ\xea*\xb3D\xf8\xf2'
#     b'p\x12\xa0\xa5\xe6\x15\x99\xd9\x91\x16\x7f\xb89\xb5\xd3\xa4\x06\xd9,f\xf1\xe4\xc6\xafP\x02\x1b\x03Cb/\xc0'
#     b'\xaf\xad0\xb1\x11\xbe\x16\xb8Q <\x8b\xcd\x96m\xe3CE\xcf\xc8\x10\x8c\xdb{bLj\xd8\xc1\x90\x9aL'
#     b'9g}l\\\x8f\x1a\x90g\xb2\xafqNF\xfa\x04\xf88Z\xcd\xe3\x02&ko\xb5\xe0\x994\x1d\xbf\xd4'
#     b'A\x91\xaayl.C\xfe\x8eY\x98\xec\xaa(G\x11e\x81\xdd\xc9\xd4w@x\x02\xe2\xe9\x05\x862G\xc6'
#     b'\x15\r\xca\xa5W\x17X\x922\x0cL\xd0\x01\xc76\xd82\xf6\x8c\xfex\x89\x9c\xca\x93\xd6j/v\xbc\x91\xc5'
#     b'\xd0\x17\xf0\x8c\x1a\x0f]\xc0\xb4?\xb5\xee\xf7\xcfU\x98.\x0b2e\x95@\xa3\x90cm\x9br\r\x13_\xcc'
#     b'\xc1J\xed\xcf\xa1\xa8\x0bR[\xd3\xa8\x9dg\xa0m7\x98\xbf\xaem\x95\xb7z\xc9\xef7\xf8\xc4\xfckh~'
#     b'\x14\xc9U\xbb\xf3Y\xc9]\x1c\xdc\xe7\xca]\nW=%\x8eJ\xadu~\xba\xeb@\x0c\x9fV\xfd\x01\x0f3'
#     b'\xbf\xdeq\x8b\x1aN\x8c\xbch\xaa\xe3\x03\x98)\\\xb2\xeb\xaa\x8f\x03s2\xa5\xc8\xbdF\x06L\x8d\xe0\x85}'
#     b"<\xd9d\x9a\xac\xdbd\xc1\xbbh\x92\x9d\x83O\xe57\xad\n\xd1\x92\xf2'?s\xb1Smh\x17\xd8\x9d;"
#     b'$h;L(\xa7\xdd3\x91\x0c\x89&\xfb\xa5;\xd2\x89\xf6\xd1>\xe6B\x03\xdb\xaaT\xaa\x9f\x8d\xa8^Q'
#     b"&[C\x9dt\x0b\x0f\xa3\x8b\x8b\x05%\x84\xba\xde{o\x88\xbd\xe7\xf4IJ\xc4\x90q&U&'-\xdf"
#     b'q\x80F\x87\xa5`\x85\x05K\xc4\xeb2O\xcb/\xb9I\xec>9"\x0c>cDw\xb8l\xa2\x88\xb9f'
#     b'tP\x1dO\x93\x8b3s\xe0\xf9\xfc9a$@\\o4\x99\xa3?\x10\x0e\xef.\x95"\xbe\x95[}\x06'
#     b'\x8b\xc7\xba\xb3\x8f\x17\xafE\xb0tx:\xee{\r\x12\xd6\x7f\xe2\tlj\xe4@~\xde\x05\xb8\x92\x8fE\xf1'
#     b's\x13N#P\xf6\xaf\xe55\x80\tlq0\x94\x97\xd1O\xee\x85\xc8\xd6`\xaf;\xa08?w\xa2\x9b\xbe'
#     b'\x88>~\x86\xedW\x07{\xf8J\xde\x8a3;\xc4\xa1\xf2$Lfz\x80;6\xfeA\x8e&\xe2\x03\x81\xe8'
#     b'\x80|\x81\xb4\x89\x9b\xd4\xbb\x9ap\x1c\xca$R\xc5R|/\x0c\xff\xae\xfb\xe6\xe5\xaa|\xd2\xddbT\xcd\xa6'
#     b'R5\x9d\xa4-\xac\x91\x06\x08\x9c\xaa\xc2SeVZ*\x15I\xce\x98!\x01p(OE\xf2\xa21\x91T'
#     b'\xfd\xe9\xb3\x00@t\xabWT\x1e\xafm\x14\xb8!\xfb;\x85\xd3\x7f\xeb-N8k;*\xba&\xdf\x00\xa9'
#     b'\x15\x7f\xa2\xa0\xa3\xe4\xd9\xee!1\xab\xd7\xa6\xb9~k\xffX\xea\xaa>\x97F\xa7D@)\xc4\xd3n\xfa7'
#     b'4\xe2\xe8\xa7\xa0wR\xf2!bY7\xc6\xe3F\x1f\xd5dN\xff\xee2\xa0a4p\xf9\x0eE\xab\x11\x83'
#     b'\x98 \xc6\x9b!k\x9c\x90\xaa\xc0\x86,*\xc8\x0b\xc3 4/b;\x16x\xe3\xe7(\xe2yQw\xefu'
#     b'\x05.\x8b\x02\xe3\x84\xe3 N\xb1:@\x9b04!\x93t\xe9\xa9t%w<T\xfb\xbc0\xd9\x13\xc2\x1c'
#     b'%\xb4\x1be\x0c\xba\n$\xf3\xfc\xca\x91\xbe__v<\xf6\xa0\xda(\xbd\x9b \x83H\x12?\x05\x9a\xb5]'
#     b'\xecx\x12b\x89T\xe5-\xc1\x18\xa6\xd0C\xf3\xcd\xcf\xca\xc2\x15*XJh\x19\xc1u\xe34\xd6\xe9k\xf7'
#     b'xJZu5\x81\x1a\x8f\xb2\x99\x91\x98\xfb\x03\x12\xc2I\n%E2{\xfc\x88\xb7?\xfb\xf8!q%<'
#     b'\x7f\x12u\xbc\x9ck\x90\x8d\x83\xe6\x12\x0cK%#wd\xdaS\rG\xf07\xaa\xdb\xd3\x97\xfb\xde\x01!\x88'
#     b'\xa0&\xef\xb0\xa0c\x88\x8diD\xf5:\xcb5C6\xb8h\xad\x8a\x14\xc2\x02\xd5\xc6O\tbV\xfd\xe6A'
#     b'3\x0e\xbd0\x00I[(\xf9\x04fv@=\x0cU\xa2\x9e+)\xbeHuC\x7f\xd0-\x17\x96\xd17h'
#     b'7\x970U\xf6\xbf\xf2K\x9e\xdd\x02\x8d\xe9\xe4\xf5kQ\x8d\xf7\xd96IV\xcc\xf9Q\x904CE\xaf\x83'
#     b'\x8f\xde\xa7[9\xbfI\x8d\xab}2&\x198\xb4>.\x90\x11\x8a\xf0\xa9T\xcb\xa5\x99/ g{\xf2L'
#     b'\x99C\x86\x87k\xab\x1eMP\xb5\xfc\x8a\xce\xb3\xecL\x07O\x9ej\x96\xba\x84\xa2PBm\x11:;\x85\x18'
#     b'E9\x1d\x80\xee\xe7\xea\x17W\xc6\x94\xc6\x1f\x02\x1d\xd48sWJ\xa03E\x14\xe7O\xbd\xff\xf8\xbd!\xd4'
#     b'\xfc\x16itbAT\xef-\xed\x10<\xa3"\xe1H\xd1m\xe7qo\x03\n\xe2Jo\x0cas\xc3\xa9\x86'
#     b'\x98(\xd0\xf5\x8a\x91\x90o\xbe\xc8\t\xf1\x8c\x13\x11\xce\xc5v@\x07\xe9V\x08\xe4\x0cR"s\xc0\x996\x01'
#     b'\xa9d\xa6\xb0\x95\xd4\x0b\x01\x11Z\xdfd\x92\xf1\x83J\xbb4\xee\x8c\xa7F\xb8\x00\x83k8\x12C@\x07i'
#     b'\x7f\x99\x08\xae\xab\x058z\x14\xc0\n!i0Q\xeb\x1c\xd3\x08,\x02\xc0\x97\x96\xd1\xa7\xda\xa5F\x94\xed\x8b'
#     b'\x9a\xf2\x04\x141\x057Cu=9\x1d<\xcec\xa160\x8e\xb0\x82\x97\xbbu\x10\xdb\xda\x07\xfb\xb9\x1dm'
#     b'\x9e\xdd52\x904\xeb\x98\xf9\xe6\x97BX\x81\xfc2\xcf$\x12g\xe1\xb7\xfb \xce\xd0\x14_\xdf\xf9;\xb0'
#     b'\xc9T\xadE7\x8f\xa24\xc7\xfe\x81\x92Z\x12\xba\xad\xf1\xf3\xb1\xc8\xa9b\xcf\xaeH\xed\xead\x9c\x08\xa5\xa9'
#     b"\xdd\xd1\xa4\x93\x94\xa0\x1d\x91\x82\x8f\x08\xd4\x0f\xa5'V92\x0f;\x85\xdd\xc0\xd7\x11j\xdcg\x11\x08\xfc\xd6"
#     b'/{\xf3\xccZ#\x9b\xc7\x81\x08\xf7XY]\xf8\x08O\x11\x84n\xfdC\x80\x8c\x7f\xe1\n\x1c\x89O\x10\xbc'
#     b'\xf3\x91\x90\xbeap\xf7\xc9\xed\xab\xdc\xa8H\xc4nl\xc3\xc8\xaa`\x0fgT\xdf\xa6\x95\x85\xb8\xb5\xbe\x17\x10'
#     b'!\x90\x0ckyA\x85\xb0\xfe\xb4\x94\x86\x86{\xd9\xf5\x91\xa1\xeb4~\xad\x1cC\xb3\x02\x02\x18\xf5v\xd9E'
#     b'8\xe8\x85\x03\xb2\xcej\x95d\xc9P\x9a\x9e!\xb8\xfb\xc2t\xcc\xa4\x10\xff\xa2\xfc^ \xd4\x8a\xf5<\x87\n'
#     b'=\xd8\x84\xb9O\xd7\x87\xe6\xe6R\x05H\xcb7$\xa1\xce\x12_R-G\xf4D"\xbd\xa2\x03O6\x1dc'
#     b'\xee\x13M\xeb*\xd2\xfa\x1a\xcb\x00\x15\xbf\xc0v\xd1\xeex^\x99\x88\xb3\xa3N\x9c-\xf5\xa1\xe4\xa5\xcb\xb4\x96'
#     b' \x83:;\x9c\x7f_78>W\x02\xa9\x9eon\x0c\x81\x8e\xeb\x96q\xbc\xfb\xab\xbdE\x86a\xf8\x03\x96'
#     b'\xe4\xe6z\xc6\x80\x9a\xd4\xcf\xc8`\x1d\xf7wy\xc3\x02Qs*\xe4\xb2i\xe9j\x13\xaa/\xd2B3R,'
#     b'\x83Nf\xb0\xefF\x85\xfb\xaa\xa5i\xc73\xf1\xf1B3\x90\xed`<\xd7f\xd6]4`\x1c\x8f.\xcc*'
#     b'\xcc\xaa\xf6\x9d\x02\xb5 J-\x06\x85 \xc4\x0c\xd3h\xe9(Z\xd9\x08\n\x80N\xech\x80\xb4{\xe8\x92Y'
#     b'\x9bZx\xa1"\x93\xb8f\xa4\xdb\xe4\xfa\xaf\xf7\xe5H\xea_y\xce\xe7\xbc\xa9U*km\xa0\\\xddA\xf1'
#     b'x\xd0\xca\x98\xeb\xf7\xa3\x17s/\xdb.\xe4\xeek\x97\xc9p\x1f\x1c*x\x19S)\x04*\xff\x95\xbf\x0f\x07'
# transactionsRoot b'\xd2v\xd6L\xfa\xa2z}\x08\xfb\xda\xa6\xa0\xf0\xd0\xf9\xd5\xdf\x06v\x8a\x08\x9c\xbc,\xb1c"-\x1f\xc2\xf7'
#     AttributeDict({'index': 55867259, 'validatorIndex': 647036, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19189994})
#     AttributeDict({'index': 55867260, 'validatorIndex': 647037, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19171976})
#     AttributeDict({'index': 55867261, 'validatorIndex': 647038, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19198993})
#     AttributeDict({'index': 55867262, 'validatorIndex': 647039, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19170031})
#     AttributeDict({'index': 55867263, 'validatorIndex': 647040, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19185984})
#     AttributeDict({'index': 55867264, 'validatorIndex': 647041, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19192650})
#     AttributeDict({'index': 55867265, 'validatorIndex': 647042, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19178882})
#     AttributeDict({'index': 55867266, 'validatorIndex': 647043, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 64862618})
#     AttributeDict({'index': 55867267, 'validatorIndex': 647044, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19196867})
#     AttributeDict({'index': 55867268, 'validatorIndex': 647045, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19192723})
#     AttributeDict({'index': 55867269, 'validatorIndex': 647046, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19217369})
#     AttributeDict({'index': 55867270, 'validatorIndex': 647047, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19180489})
#     AttributeDict({'index': 55867271, 'validatorIndex': 647048, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19180936})
#     AttributeDict({'index': 55867272, 'validatorIndex': 647049, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19197136})
#     AttributeDict({'index': 55867273, 'validatorIndex': 647050, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19194312})
#     AttributeDict({'index': 55867274, 'validatorIndex': 647051, 'address': '0xB9D7934878B5FB9610B3fE8A5e441e8fad7E293f', 'amount': 19182915})
# withdrawalsRoot b'\x14D\xcd\xad{y\xbb_\xc5i\x89\xc4Q\x1d\xee\xfbC\xe9\x08J\xa3\xdcyl\xca\xe3\xb6\xa3\xd0\xf7\xab\x8d'

# %%
# Get block data from Alchemy
block_hash_alc = Alchemy.to_hex(alchemy.core.get_block('latest')['hash'])
block_num_alc = Alchemy.to_hex(alchemy.core.get_block('latest')['number'])

# Get block data from Web3
block_hash_w3 = w3.eth.get_block('latest')['hash']
block_num_w3 = w3.eth.get_block('latest')['number']

# Cross reference block has between Alchemy query and Web3 query
print(block_hash_alc)
print(block_data_w3.hex())
print(int(block_num_alc,16))
print(block_num_w3)

# Gets all transaction receipts for a given block hash.
block_receipts_alc = alchemy.core.get_transaction_receipts(block_hash=block_hash_alc)
block_receipts_alc = w3.eth.get_block('latest')['number']

# Set a block number as the 'progenitor block' of the database.
set_key(dotenv_path='../.env', key_to_set="PROGENITOR_BLOCK", value_to_set=block_num_w3)

# Create function to listen for new block after progenitor block


# Create function to dig existing blocks starting from progenitor block
def export_latest_blocks(interval=60, blocks_to_export=5):
    while True:
        latest_block_number = alchemy.core.get_block_number()
        for i in range(latest_block_number):
            block = alchemy.core.get_block_with_transactions(latest_block_number - i)
            export_block_to_mongo(block)
        time.sleep(interval)

# Create function to send new blocks to mongodb
# Create funciton to send old blocks to mongodb

# Disconnection Functions
# https://chatgpt.com/share/8c7a65c4-b5da-4db5-b9c5-d7fa1ebbd28e
# Create function to detect shutdown of mongodb client
# Create function for storing last stable state before shutdown of mongodb client
# Create function for graceful shutdown

# Startup Functions
# Create function to check if mongodb client is running
# Create function to start from last stable state
# Create function to run send-to-mongodb functions if client is running
# Out:
# 0x95435f66e3eb905ef1a0fd15fd699809adda098c6f53ca547d1ba6998f7bbf53
# 0xd5f87fb7af787f02014dd721e5e42b2b076aa32d249c50f798f48c5209d2d6ef
# 20526733
# 20526733

# %%
# 1st startup
# Latest block: 50
# F1 Gets transaction details of latest block: 50
# F1 sets object latest_block_current(50)
# On finish, F1 sets latest_block_finished(50) and sets latest_block_current(51)
# F1 waits for matching block

# F2 gets transaction details of latest block -1
# F2 sets object archive_block_current(49)
# On finish archive F2 sets object archive_block_finished(49) and sets archive_block_current(48)

# %%
# Initial setup
# Latest block: 50
# Set latest_block_current = 50
# Set archive_block_current = 49

# Function F1 (Latest block processor)
# F1 gets transaction details of latest_block_current
# F1 processes and stores data for latest_block_current
# On finish, F1 sets latest_block_finished = latest_block_current
# F1 increments latest_block_current
# F1 waits for new block if latest_block_current > chain height

# Function F2 (Archive block processor)
# F2 gets transaction details of archive_block_current
# F2 processes and stores data for archive_block_current
# On finish, F2 sets archive_block_finished = archive_block_current
# F2 decrements archive_block_current
# F2 stops if archive_block_current < 0 or reaches desired historical point

# Error handling and retry mechanism for both F1 and F2

# Periodic consistency check between latest_block_finished and archive_block_finished

# Logging and monitoring for both functions

# %%
# Get unique column names

unique_keys = set()

for receipt in block_receipts:
    unique_keys.update(receipt.keys())

print("Unique keys in block receipts: ")
for key in unique_keys:
    print(key)

# %%
# CSV Write Function

import csv
from datetime import datetime

# Define the CSV file name
csv_filename = f"transaction_receipts_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"

# Write to CSV
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=columns)
    
    # Write the header
    writer.writeheader()
    
    # Write the data
    for receipt in block_receipts:
        row = {column: receipt.get(column, None) for column in columns}
        writer.writerow(row)

print(f"Transaction receipts exported to {csv_filename}")

# %%
# https://chatgpt.com/share/9d0b1717-9189-44c8-bc8e-62a1e96b4bf5
# 2.2.alchemy-sdk.py/web3.py (Jupyter_Notebook) > 2.5 MongoDB > 3.Kafka

# Set up MongoDB connection
client = MongoClient('mongodb://localhost:27017/')
db = client['blockchain']
collection = db['blocks']

# Function to export block data to MongoDB
def export_block_to_mongo(block):
    block_data = {
        'number': block['number'],
        'hash': block['hash'],
        'parentHash': block['parentHash'],
        'nonce': block['nonce'],
        'transactions': [
            {
                'hash': tx['hash'],
                'from': tx['from'],
                'to': tx.get('to'),
                'value': tx['value'],
                'gas': tx['gas'],
                'gasPrice': tx['gasPrice'],
                'input': tx['input'],
            } for tx in block['transactions']
        ]
    }
    collection.insert_one(block_data)
    print(f"Exported block {block['number']} to MongoDB")

# Main loop to fetch and export the latest blocks at intervals
def export_latest_blocks(interval=60, blocks_to_export=5):
    while True:
        latest_block_number = alchemy.core.get_block_number()
        for i in range(blocks_to_export):
            block = alchemy.core.get_block_with_transactions(latest_block_number - i)
            export_block_to_mongo(block)
        time.sleep(interval)

# Main guard
# if __name__ == "__main__":
#     export_latest_blocks(interval=60, blocks_to_export=5)

# %%
# https://chatgpt.com/share/7d318aa6-1b26-4350-a8f3-44db254c73b9

# 1. Structure Data for Kafka >

import json

block_data = json.dumps(latest_block, default=str)

# 2. Send Data to Kafka

from kafka import KafkaProducer

producer = KafkaProducer(bootstrap_servers='localhost:9092', value_serializer=lambda v: json.dumps(v).encode('utf-8'))

producer.send('ethereum-blocks', block_data)
producer.flush()

# 3. Kafka to Spark Integration

# In terminal

# pyspark --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.1.1

# %%
# https://chatgpt.com/share/beb9384f-36ae-4f4a-8802-84d1a9346bea

# 1. Create Kafka Topics
# In terminal
# kafka-topics.sh --create --topic ethereum-data --bootstrap-server localhost:9092 --partitions 3 --replication-factor 1

# 2. Send Data to Kafka

from confluent_kafka import Producer
import json

producer_config = {'bootstrap.servers': 'localhost:9092'}
producer = Producer(producer_config)

def delivery_report(err, msg):
    if err is not None:
        print(f"Message delivery failed: {err}")
    else:
        print(f"Message delivered to {msg.topic()} [{msg.partition()}]")

def produce_message(data):
    producer.produce('ethereum-data', key='key', value=json.dumps(data), callback=delivery_report)
    producer.flush()

# Example data from Ethereum-Alchemy pipeline
eth_data = {
    'block_number': 123456,
    'transaction_hash': '0xabc123...',
    'value': 10.5
}
produce_message(eth_data)

# 3. Install PySpark
# In Terminal
# pip install pyspark

# 4. Configure Spark Streaming with Kafka

from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json, col
from pyspark.sql.types import StructType, StructField, StringType, DoubleType

# Initialize Spark session
spark = SparkSession.builder \
    .appName("EthereumKafkaSpark") \
    .getOrCreate()

# Define the schema for your Ethereum data
schema = StructType([
    StructField("block_number", StringType(), True),
    StructField("transaction_hash", StringType(), True),
    StructField("value", DoubleType(), True)
])

# Read stream from Kafka topic
df = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", "ethereum-data") \
    .load()

# Decode the JSON data and apply schema
json_df = df.selectExpr("CAST(value AS STRING)") \
            .select(from_json(col("value"), schema).alias("data")) \
            .select("data.*")

# Process and display the streaming data
query = json_df.writeStream \
               .outputMode("append") \
               .format("console") \
               .start()

query.awaitTermination()

# 5. Run Spark Streaming Job
